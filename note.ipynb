# %%
卷积神经网络训练模型中，参数在每次训练完后没有更新的可能原因有以下几点：

1、学习率过小：学习率设置过小可能导致模型参数更新的步长过小，使得模型参数更新缓慢甚至停滞不动。可以尝试增大学习率。

2、数据集问题：如果数据集质量较差或者样本分布不均衡，可能导致模型训练困难，参数难以收敛。可以尝试进行数据预处理、数据增强或调整样本权重。

3、梯度消失/梯度爆炸：当网络层数较多时，反向传播中的梯度可能会出现消失或爆炸的情况，导致参数更新异常。可以尝试使用激活函数、参数初始化方法或梯度剪裁等技巧来缓解该问题。

4、损失函数选择不合适：选择不合适的损失函数可能导致训练过程中的梯度计算出错或优化方向不正确，使得参数难以更新。可以尝试换用其他合适的损失函数。

5、网络结构设计问题：模型结构设计不合理或超参数设置不当也可能导致参数难以更新。可以尝试调整网络结构或调整超参数。

6、训练步骤问题：可能存在训练步骤上的错误，例如忘记调用优化器进行参数更新、未正确设置训练循环等。可以检查训练代码是否正确。

7、数据规模问题：如果数据集规模较小，模型可能容易过拟合，参数更新困难。可以尝试增加数据集规模或使用正则化方法缓解过拟合。

以上是一些可能导致参数在每次训练后没有更新的原因，可以根据具体情况进行排查和调整。
